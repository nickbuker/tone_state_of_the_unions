# %%
import pandas as pd
import matplotlib.pyplot as plt
from src import plotting

# %matplotlib inline

# %%
df_anger = pd.read_csv('./data/chunk_anger.csv', index_col=0)
df_disgust = pd.read_csv('./data/chunk_disgust.csv', index_col=0)
df_sadness = pd.read_csv('./data/chunk_sadness.csv', index_col=0)
df_joy = pd.read_csv('./data/chunk_joy.csv', index_col=0)
df_fear = pd.read_csv('./data/chunk_fear.csv', index_col=0)

# %%
df_anger.head()
# Out:
#         chunk1    chunk2    chunk3    chunk4    chunk5    chunk6    chunk7  \
# 1961  0.088899  0.196587  0.173543  0.496760  0.133172  0.147623  0.281902
# 1962  0.137120  0.102074  0.517985  0.276896  0.446091  0.157693  0.190420
# 1963  0.132646  0.152613  0.159996  0.102126  0.187793  0.144062  0.183519
# 1964  0.134200  0.260388  0.290051  0.323909  0.062149  0.057158  0.107134
# 1965  0.108288  0.087406  0.115052  0.168999  0.238305  0.204492  0.537481
#
#         chunk8    chunk9   chunk10    ...      chunk31   chunk32   chunk33  \
# 1961  0.351872  0.162616  0.096089    ...     0.067941  0.549941  0.185626
# 1962  0.502047  0.175252  0.173117    ...     0.146230  0.145502  0.114594
# 1963  0.109542  0.122186  0.553422    ...     0.111572  0.569527  0.514794
# 1964  0.471488  0.126195  0.010148    ...     0.292573  0.154395  0.323490
# 1965  0.450013  0.120727  0.449879    ...     0.164096  0.266446  0.034342
#
# ...

# %%
plotting.tone_chunks(df_anger, 'Anger', 'r')

# %%
plotting.tone_chunks(df_disgust, 'Disgust', 'c')

# %%
plotting.tone_chunks(df_sadness, 'Sadness', 'b')

# %%
plotting.tone_chunks(df_joy, 'Joy', 'g')
plt.savefig('./images/joy_chunks.png')

# %%
plotting.tone_chunks(df_fear, 'Fear', 'm')
